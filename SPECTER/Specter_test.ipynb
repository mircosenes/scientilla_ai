# %% [markdown]
# ## Connect DB

# %%
import psycopg2
import pandas as pd
import json

conn = psycopg2.connect(
    dbname="scientilla",
    user="postgres",
    password="pwd",
    host="localhost",
    port=5444
)
cur = conn.cursor()

# %%
def clean_item(item):
    title = item.get("title") or ""
    abstract = item.get("abstract") or ""
    title = item.get("title") or ""
    abstract = item.get("abstract") or ""
    if abstract:
      text = f"{title}. {abstract}"
    else:
      text = f"{title}."
    return text.strip()

# %% [markdown]
# ## Testing

# %% [markdown]
# #### From db

# %%
from sentence_transformers import SentenceTransformer
from sklearn.cluster import KMeans
import numpy as np

model = SentenceTransformer("sentence-transformers/allenai-specter")

def embedding_to_pgvector_str(vec):
    """From np.array to string '[v1,v2,...]' for ::vector."""
    return "[" + ",".join(str(float(x)) for x in vec.tolist()) + "]"

def search(query, top_k=5):
    # query embedding
    q_emb = model.encode([query], convert_to_numpy=True, normalize_embeddings=True)[0]
    q_emb_str = embedding_to_pgvector_str(q_emb)

    # SQL query with pgvector cosine distance
    sql = """
    WITH q AS (
        SELECT %s::vector AS emb
    )
    SELECT
        ri.id,
        ri.data,
        ri.embedding <=> q.emb AS distance
    FROM research_item AS ri
    JOIN research_item_type AS rit
        ON ri.research_item_type_id = rit.id
    JOIN q
        ON TRUE
    WHERE rit.type = 'publication'
      AND ri.embedding IS NOT NULL
    ORDER BY ri.embedding <=> q.emb
    LIMIT %s;
    """

    with conn.cursor() as cur:
        cur.execute(sql, (q_emb_str, top_k))
        rows = cur.fetchall()

    print(f"\n=== Query: {query!r} ===")

    for i, (doc_id, data_json, distance) in enumerate(rows, start=1):
        # Convert distance to similarity score
        score = 1.0 - float(distance)

        text = clean_item(data_json)
        preview = text[:200] + ("..." if len(text) > 200 else "")

        print(f"\n[{i}] id={doc_id}  score={score:.3f}")
        print(f"     text: {preview}")

# %%
test_queries = ['renewable energies','heart', 'cardiology', 'nature','biology']

for q in test_queries:
    search(q, top_k=5)
# Out:
# === Query: 'renewable energies' ===
#
# [1] id=2465  score=0.753
#      text: Cheap and easily processable electrode/electrolytes for next-generation sodium-ion batteries. Electrochemical energy storage is of increasing importance to allow large-scale integration of intermitten...
#
# [2] id=2596  score=0.745
#      text: Charger-mediated energy transfer for quantum batteries: An open-system approach. The energy charging of a quantum battery is analyzed in an open quantum setting, where the interaction between the batt...
#
# [3] id=2093  score=0.723
#      text: A new solvothermal approach to obtain nanoparticles in the Cu3SnS4–Cu2FeSnS4 join. In the field of the renewables, a large effort has been devoted in the last years to obtain conventional and new mate...
#
# [4] id=2454  score=0.719
#      text: Bio-oil from pyrolysis of wood pellets using a microwave multimode oven and different microwave absorbers. Wood pellets were pyrolyzed using a microwave oven and different microwave power, apparatus s...
#
# [5] id=1994  score=0.715
#      text: Solubility of H2-CH4 mixtures in brine at underground hydrogen storage thermodynamic conditions. Concerning the emerging power-to-gas technologies, which are considered the most promising technology f...
#
# === Query: 'heart' ===
#
# [1] id=2587  score=0.755
#      text: Artificial empathy: New frontiers.
#
# [2] id=2004  score=0.741
#      text: A regularized matrix factorization approach to induce structured sparse-low-rank solutions in the EEG inverse problem. We consider the estimation of the Brain Electrical Sources (BES) matrix from nois...
#
# [3] id=2651  score=0.740
#      text: How to serve our members better.
#
# [4] id=2456  score=0.736
#      text: Scorepochs: A Computer-Aided Scoring Tool for Resting-State M/EEG Epochs. M/EEG resting-state analysis often requires the definition of the epoch length and the criteria in order to select which epoch...
#
# [5] id=1874  score=0.734
#      text: Solving structured sparsity regularization with proximal methods. Proximal methods have recently been shown to provide effective optimization procedures to solve the variational problems defining the ...
#
# === Query: 'cardiology' ===
#
# [1] id=1813  score=0.737
#      text: Effect of Ivabradine in dilated cardiomyopathy from Duchenne muscular dystrophy: A chance for slowing progression of heart failure?.
#
# [2] id=2131  score=0.733
#      text: Vasopressin and terlipressin in adult vasodilatory shock.
#
# [3] id=2543  score=0.707
#      text: AngioLab-A software tool for morphological analysis and endovascular treatment planning of intracranial aneurysms. Determining whether and how an intracranial aneurysm should be treated is a tough dec...
#
# [4] id=2189  score=0.706
#      text: Retina image analysis and ocular telehealth: The oak ridge national laboratory-hamilton eye institute case study. Automated retina image analysis has reached a high level of maturity in recent years, ...
#
# [5] id=2044  score=0.689
#      text: Pharmacological approaches to cystic fibrosis.
#
# === Query: 'nature' ===
#
# [1] id=2368  score=0.810
#      text: Guest Editorial Special Section on Learning in Non-(geo)metric Spaces. Traditional machine learning and pattern recognition techniques are intimately linked to the notion of feature spaces. Adopting t...
#
# [2] id=1953  score=0.790
#      text: Approximate Log-Hilbert-Schmidt distances between covariance operators for image classification. This paper presents a novel framework for visual object recognition using infinite-dimensional covarian...
#
# [3] id=2587  score=0.790
#      text: Artificial empathy: New frontiers.
#
# [4] id=2509  score=0.788
#      text: Learning sets with separating kernels. We consider the problem of learning a set from random samples. We show how relevant geometric and topological properties of a set can be studied analytically usi...
#
# [5] id=2651  score=0.785
#      text: How to serve our members better.
#
# === Query: 'biology' ===
#
# [1] id=2488  score=0.805
#      text: Trained through generations.
#
# [2] id=2585  score=0.804
#      text: The synapsins.
#
# [3] id=2651  score=0.796
#      text: How to serve our members better.
#
# [4] id=2509  score=0.789
#      text: Learning sets with separating kernels. We consider the problem of learning a set from random samples. We show how relevant geometric and topological properties of a set can be studied analytically usi...
#
# [5] id=2587  score=0.783
#      text: Artificial empathy: New frontiers.
